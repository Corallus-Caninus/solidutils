# %%
from solid import *
from solid.utils import *
from math import sin, cos, radians, degrees
# Encapsulated seperate from cyclone hull due to complexity and reuse of code for vacuumManifold

# TODO: should constraint safety be implemented here? in extrude_intake_manifold?
# r = viewscad.Renderer(
#     openscad_exec="C:\Program Files\OpenSCAD\openscad.exe"
# )  # Point this to your openscad executable

# %%
def construct_polygon(sides, radius_major, radius_minor, offset):
    """
    Builds a planar 2D regular polygon with a given offset

    Parameters:
        polyPoints: number of points for the reglar polygon
        radius: the radius of a circle sweeping the polygon points
        offset: shift along z axis, useful for extrusions
    Returns:
        a list of Point3 entries defining the regular polygon
    """
    geometry = []
    for i in range(0, sides):
        angle = i * 360 / sides
        x = radius_major * sin(radians(angle))
        y = radius_minor * cos(radians(angle))

        geometry.append(Point3(x, y, offset))
    return geometry

# %%
def extrude_intake_manifold(intake_resolution, exhaust_slit, exhaust_width, exhaust_length):
    '''
    Extrudes an intake manifold for cyclone filtration.
    Parameters:
        intake_resolution: how many segments to be used for the final polygon (circle theroetically has infinite)
        exhaust_slit: length of slit that enters the vortex
        exhaust_width: width of slit that enters the vortex and also acts as cyclone guide (minimize)
        exhaust_length: extruded distance of intake manifold
    Returns:
        a Hull() consisting of the segments created with construct_polygon
    '''
    inlet_radius = sqrt(exhaust_slit*exhaust_width/pi)
    intakeManifold = down(1)(cube([exhaust_slit, exhaust_width, 1], center=True))
#     segmentedIntakeManifold = []  # return value
    # constants are okay here as this module is meant to be transformed from origin
#     segmentedIntakeManifold.append(
# #         down(1)(scale([exhaust_slit, exhaust_width, 1])(cube(center=True)))
#         down(1)(cube([exhaust_slit, exhaust_width, 1], center=True))
#     )  # exhaust square (initial object)
    # raderator is the radius iterator for
    # rectangle to circle transform
    
    #TODO: this is the problem
    raderator_major = (exhaust_slit/2 - inlet_radius)/intake_resolution
    raderator_minor = (exhaust_width/2 - inlet_radius)/intake_resolution
        

    inlet_radius_major = exhaust_slit/2
    inlet_radius_minor = exhaust_width/2

    length_iterator = exhaust_length/intake_resolution
    for seg in range(1, intake_resolution):
        inlet_radius_major -= raderator_major
        inlet_radius_minor -= raderator_minor
        
        print('comparing area elipse: {} with rectangle: {} '.format( \
                                pi*inlet_radius_major*inlet_radius_minor, exhaust_slit*exhaust_width))
        
        length_iterator += exhaust_length/intake_resolution
        
        intakeManifold += up(length_iterator)(scale([inlet_radius_major, inlet_radius_minor])(cylinder(center=True)))

        intakeManifold+=up(length_iterator+length_iterator)(cylinder(r=inlet_radius, center=True))
    return hull()(intakeManifold)

# %%
############# Write to File (for logging) #############
intakeSlitHeight = 7
intakeSlitWidth = 2
wallWidth = 1
intakeSlitLength = 20
solution = extrude_intake_manifold( \
            intake_resolution=100, \
            exhaust_slit=intakeSlitHeight + wallWidth, \
            exhaust_width=intakeSlitWidth + wallWidth,\
            exhaust_length=intakeSlitLength)
scad_render_to_file(
    solution,
    "intakeManifold.scad"
)
################################################
# Out:
# comparing area elipse: 18.94965081842851 with rectangle: 24
# comparing area elipse: 19.048764089942402 with rectangle: 24
# comparing area elipse: 19.146895736080427 with rectangle: 24
# comparing area elipse: 19.244045756842596 with rectangle: 24
# comparing area elipse: 19.340214152228903 with rectangle: 24
# comparing area elipse: 19.435400922239346 with rectangle: 24
# comparing area elipse: 19.529606066873928 with rectangle: 24
# comparing area elipse: 19.622829586132653 with rectangle: 24
# comparing area elipse: 19.71507148001551 with rectangle: 24
# comparing area elipse: 19.80633174852251 with rectangle: 24
# comparing area elipse: 19.89661039165365 with rectangle: 24
# comparing area elipse: 19.985907409408924 with rectangle: 24
# comparing area elipse: 20.074222801788338 with rectangle: 24
# comparing area elipse: 20.16155656879189 with rectangle: 24
# comparing area elipse: 20.247908710419583 with rectangle: 24
# comparing area elipse: 20.33327922667141 with rectangle: 24
# comparing area elipse: 20.417668117547382 with rectangle: 24
# comparing area elipse: 20.501075383047493 with rectangle: 24
# comparing area elipse: 20.583501023171735 with rectangle: 24
# comparing area elipse: 20.66494503792012 with rectangle: 24
# comparing area elipse: 20.745407427292648 with rectangle: 24
# comparing area elipse: 20.824888191289308 with rectangle: 24
# comparing area elipse: 20.903387329910107 with rectangle: 24
# comparing area elipse: 20.98090484315505 with rectangle: 24
# comparing area elipse: 21.057440731024126 with rectangle: 24
# comparing area elipse: 21.132994993517343 with rectangle: 24
# comparing area elipse: 21.2075676306347 with rectangle: 24
# comparing area elipse: 21.281158642376194 with rectangle: 24
# comparing area elipse: 21.353768028741825 with rectangle: 24
# comparing area elipse: 21.4253957897316 with rectangle: 24
# comparing area elipse: 21.49604192534551 with rectangle: 24
# comparing area elipse: 21.565706435583554 with rectangle: 24
# comparing area elipse: 21.634389320445745 with rectangle: 24
# comparing area elipse: 21.70209057993207 with rectangle: 24
# comparing area elipse: 21.76881021404253 with rectangle: 24
# comparing area elipse: 21.834548222777137 with rectangle: 24
# comparing area elipse: 21.89930460613588 with rectangle: 24
# comparing area elipse: 21.96307936411876 with rectangle: 24
# comparing area elipse: 22.02587249672578 with rectangle: 24
# comparing area elipse: 22.087684003956937 with rectangle: 24
# comparing area elipse: 22.148513885812232 with rectangle: 24
# comparing area elipse: 22.20836214229167 with rectangle: 24
# comparing area elipse: 22.267228773395242 with rectangle: 24
# comparing area elipse: 22.32511377912295 with rectangle: 24
# comparing area elipse: 22.382017159474806 with rectangle: 24
# comparing area elipse: 22.437938914450793 with rectangle: 24
# comparing area elipse: 22.49287904405092 with rectangle: 24
# comparing area elipse: 22.546837548275185 with rectangle: 24
# comparing area elipse: 22.599814427123594 with rectangle: 24
# comparing area elipse: 22.651809680596134 with rectangle: 24
# comparing area elipse: 22.702823308692818 with rectangle: 24
# comparing area elipse: 22.75285531141364 with rectangle: 24
# comparing area elipse: 22.8019056887586 with rectangle: 24
# comparing area elipse: 22.849974440727696 with rectangle: 24
# comparing area elipse: 22.897061567320936 with rectangle: 24
# comparing area elipse: 22.943167068538312 with rectangle: 24
# comparing area elipse: 22.988290944379823 with rectangle: 24
# comparing area elipse: 23.032433194845478 with rectangle: 24
# comparing area elipse: 23.075593819935268 with rectangle: 24
# comparing area elipse: 23.117772819649197 with rectangle: 24
# comparing area elipse: 23.15897019398727 with rectangle: 24
# comparing area elipse: 23.199185942949477 with rectangle: 24
# comparing area elipse: 23.23842006653582 with rectangle: 24
# comparing area elipse: 23.27667256474631 with rectangle: 24
# comparing area elipse: 23.31394343758093 with rectangle: 24
# comparing area elipse: 23.35023268503969 with rectangle: 24
# comparing area elipse: 23.385540307122593 with rectangle: 24
# comparing area elipse: 23.419866303829632 with rectangle: 24
# comparing area elipse: 23.453210675160808 with rectangle: 24
# comparing area elipse: 23.48557342111613 with rectangle: 24
# comparing area elipse: 23.516954541695583 with rectangle: 24
# comparing area elipse: 23.547354036899172 with rectangle: 24
# comparing area elipse: 23.576771906726908 with rectangle: 24
# comparing area elipse: 23.60520815117878 with rectangle: 24
# comparing area elipse: 23.632662770254786 with rectangle: 24
# comparing area elipse: 23.659135763954936 with rectangle: 24
# comparing area elipse: 23.68462713227922 with rectangle: 24
# comparing area elipse: 23.709136875227646 with rectangle: 24
# comparing area elipse: 23.73266499280021 with rectangle: 24
# comparing area elipse: 23.755211484996916 with rectangle: 24
# comparing area elipse: 23.776776351817755 with rectangle: 24
# comparing area elipse: 23.797359593262733 with rectangle: 24
# comparing area elipse: 23.816961209331854 with rectangle: 24
# comparing area elipse: 23.83558120002511 with rectangle: 24
# comparing area elipse: 23.853219565342506 with rectangle: 24
# comparing area elipse: 23.86987630528404 with rectangle: 24
# comparing area elipse: 23.885551419849715 with rectangle: 24
# comparing area elipse: 23.900244909039525 with rectangle: 24
# comparing area elipse: 23.913956772853478 with rectangle: 24
# comparing area elipse: 23.926687011291566 with rectangle: 24
# comparing area elipse: 23.93843562435379 with rectangle: 24
# comparing area elipse: 23.94920261204016 with rectangle: 24
# comparing area elipse: 23.958987974350663 with rectangle: 24
# comparing area elipse: 23.967791711285305 with rectangle: 24
# comparing area elipse: 23.975613822844092 with rectangle: 24
# comparing area elipse: 23.98245430902701 with rectangle: 24
# comparing area elipse: 23.98831316983407 with rectangle: 24
# comparing area elipse: 23.99319040526527 with rectangle: 24
# comparing area elipse: 23.997086015320605 with rectangle: 24
# True
